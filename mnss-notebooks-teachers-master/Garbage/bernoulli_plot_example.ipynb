# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
from plot import *
import math as m

# %%
positions = np.array([
    [0, 0],
    [1, 0],
])

conn = [
    [0, 1],
]

# %%
plot_structure(positions, conn)

# %%
displacement = [[0, 0.2, -np.pi/6], [0, 0, 0]]
plot_structure(positions, conn, displacement = displacement)

# %%
displacement = [[0, 0., np.pi/6], [0, 0, -np.pi/6]]
plot_structure(positions, conn, displacement = displacement)

# %%
positions = np.array([
    [0, 0],
    [0, 1],
    [1, 1],
])

conn = [
    [0, 1],
    [1, 2],
]

# %%
plot_structure(positions, conn)

# %%
displacement = [[0, 0, 0], [0, 0., np.pi/6], [0, 0, 0]]
plot_structure(positions, conn, displacement = displacement)

# %%
displacement = [[0, 0, 0], [.2, .2, np.pi/6], [0, 0, 0]]
plot_structure(positions, conn, displacement = displacement)
